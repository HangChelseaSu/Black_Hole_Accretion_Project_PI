# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a
# Out:
# array([0.000e+00, 1.000e-04, 2.000e-04, ..., 9.997e-01, 9.998e-01,
#        9.999e-01])

# %%
a = np.arange(0, 1, 0.0001)
b = np.sqrt(1 - a**2)
alpha = 0.000000009
S = 1/(1-alpha) * np.log(a**(2*alpha) + b**(2*alpha))
S_2 = -1 * a**2 * np.log2(a**2) - b**2 * np.log2(b**2)
plt.plot(a**2, S, label='Renyi entanglement entropy')
plt.plot(a**2, S_2, label='Von Neumann entropy')
plt.title(r'$\alpha -> 1$')
plt.xlabel(r'$a^2$')
plt.ylabel(r'$S$')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_31659/4275204604.py:5: RuntimeWarning: divide by zero encountered in log2
#   S_2 = -1 * a**2 * np.log2(a**2) - b**2 * np.log2(b**2)
# /tmp/ipykernel_31659/4275204604.py:5: RuntimeWarning: invalid value encountered in multiply
#   S_2 = -1 * a**2 * np.log2(a**2) - b**2 * np.log2(b**2)
