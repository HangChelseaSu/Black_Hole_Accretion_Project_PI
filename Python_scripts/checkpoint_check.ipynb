# %%
import matplotlib.pyplot as plt
import numpy as np
import discopy.util as util
import discopy.plot as plot
import discopy.geom as geom
from pathlib import Path
plt.style.use('ggplot')

# %%
checkpoint = '/gpfs/hsu/BH_disco_runs/cb_circular_1000_orbits_v2/checkpoint_0000.h5'
t, r, phi, z, prim, dat = util.loadCheckpoint(checkpoint)

# %%
np.unique(r), 5.14314636e-01 - 5.05647629e-01
# Out:
# (array([4.59460659e-03, 1.07344528e-02, 1.75082823e-02, 2.43927216e-02,
#         3.13296747e-02, 3.83033758e-02, 4.53078304e-02, 5.23403017e-02,
#         5.93993948e-02, 6.64843506e-02, 7.35947435e-02, 8.07303366e-02,
#         8.78910064e-02, 9.50767009e-02, 1.02287415e-01, 1.09523177e-01,
#         1.16784037e-01, 1.24070059e-01, 1.31381324e-01, 1.38717918e-01,
#         1.46079934e-01, 1.53467475e-01, 1.60880642e-01, 1.68319546e-01,
#         1.75784295e-01, 1.83275005e-01, 1.90791790e-01, 1.98334768e-01,
#         2.05904058e-01, 2.13499780e-01, 2.21122058e-01, 2.28771013e-01,
#         2.36446771e-01, 2.44149457e-01, 2.51879196e-01, 2.59636117e-01,
#         2.67420348e-01, 2.75232018e-01, 2.83071257e-01, 2.90938195e-01,
#         2.98832965e-01, 3.06755699e-01, 3.14706529e-01, 3.22685590e-01,
#         3.30693017e-01, 3.38728945e-01, 3.46793509e-01, 3.54886848e-01,
#         3.63009098e-01, 3.71160398e-01, 3.79340887e-01, 3.87550704e-01,
# ...
